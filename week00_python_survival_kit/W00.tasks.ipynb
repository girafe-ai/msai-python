# %% [markdown]
# # Seminar 1. Python Survival Kit
#
# These exercises ask you to apply the constructs from the seminar in new situations: filter data, compare results, understand object mutation, and combine several operations.
#
# Complete the solution cells in this notebook using Python 3. Define the data directly in your code: `input()` is not needed. Functions should return their results rather than print them. In Exercise 3, write down your prediction before running the code. Add at least one test case of your own to each exercise.
#
# You can run the examples containing `assert` after defining your function: Python will raise an error if a condition is false. Exercise 7 is optional.

# %% [markdown]
# ## How to use this notebook
#
# 1. Read each exercise and complete its **Your solution** cell. Replace the `raise NotImplementedError(...)` line with your implementation.
# 2. Run your solution cell, then the **Example checks** cell with `Shift+Enter`. Checks are expected to fail until you implement the function. Passing checks produce no output.
# 3. Add at least one test case in **Your own checks** and write your explanations in the answer cells. Double-click a Markdown cell to edit it.
# 4. In Exercise 3, record your prediction before running the demonstration.
#
# Use Python 3; no third-party packages are required. Exercise 7 is optional. Before submitting, restart the kernel and run the exercises you have completed from top to bottom. Save this notebook with your solutions and explanations.

# %% [markdown]
# ## 1. Deliveries within the neighborhood
#
# A courier starts at `(0, 0)` and moves only along the coordinate axes. The distance to a point `(x, y)` is `abs(x) + abs(y)`.
#
# Orders are given as a list of tuples `(name, x, y)`. Write a function `nearby_orders(orders, radius)` that returns pairs `(name, distance)` for orders whose distance is at most `radius`. The radius is a nonnegative integer, and the coordinates are integers.
#
# Preserve the original order of the orders, including duplicates. Use a list comprehension and tuple unpacking. Do not modify the original list.

# %% [markdown]
# ### Your solution

# %%
def nearby_orders(orders, radius):
    # TODO: implement this function.
    raise NotImplementedError("Complete Exercise 1")

# %% [markdown]
# ### Example checks
#
# Run this cell after implementing your function.

# %%
orders = [("A", 1, 2), ("B", -2, 0), ("C", 3, 3), ("D", 0, 0)]
assert nearby_orders(orders, 3) == [("A", 3), ("B", 2), ("D", 0)]
assert nearby_orders(orders, 0) == [("D", 0)]
assert nearby_orders([], 5) == []

# %% [markdown]
# Create a test case for an order with negative coordinates whose distance is exactly equal to the radius.

# %% [markdown]
# **Your explanation or observations:**
#
# _Write your answer to the exercise question here._

# %% [markdown]
# ### Your own checks
#
# Add at least one test case. Include any specific case requested in the exercise.

# %%
# Add your own checks here.

# %% [markdown]
# ## 2. Who improved their score?
#
# You are given three lists of equal length: `names`, `before`, and `after`, containing names and scores before and after a practice session. Scores are integers.
#
# Write a function `improvements(names, before, after)` that returns tuples `(number, name, increase)` only for students whose scores increased.
#
# The number is the student's position **in the original lists**, starting from one. Preserve the original order. Use `zip` and `enumerate`, without accessing elements by index. Do not modify the input lists.

# %% [markdown]
# ### Your solution

# %%
def improvements(names, before, after):
    # TODO: implement this function.
    raise NotImplementedError("Complete Exercise 2")

# %% [markdown]
# ### Example checks
#
# Run this cell after implementing your function.

# %%
names = ["Alice", "Bob", "Charlie", "Diana"]
before = [70, 80, 60, 90]
after = [70, 85, 58, 97]
assert improvements(names, before, after) == [(2, "Bob", 5), (4, "Diana", 7)]
assert improvements(["Alice"], [70], [70]) == []
assert improvements([], [], []) == []

# %% [markdown]
# Explain why numbering the filtered list can produce an incorrect result.

# %% [markdown]
# **Your explanation or observations:**
#
# _Write your answer to the exercise question here._

# %% [markdown]
# ### Your own checks
#
# Add at least one test case. Include any specific case requested in the exercise.

# %%
# Add your own checks here.

# %% [markdown]
# ## 3. What did the function change outside its scope?
#
# Without running the code, write down the output of all three `print` statements:

# %% [markdown]
# **Your prediction (before running):**
#
# ```text
# First print:
# Second print:
# Third print:
# ```

# %%
def prepare(values):
    values.append(0)
    values = values + [1]
    return values


original = [5]
alias = original
result = prepare(original)

print(original)
print(result)
print(alias is original, result is original)

# %% [markdown]
# Run the code to check your prediction, then explain:
#
# 1. Which operation modifies the existing list, and which creates a new one?
# 2. Why does assigning to `values` inside the function not rebind the name `original` outside it?
# 3. Which list does `alias` refer to after the call?
#
# Now write `prepared_copy(values)`: the function should return a new list with `0` and `1` appended at the end, leaving the original list unchanged.

# %% [markdown]
# **Your explanation (questions 1–3):**
#
# _Write your answers here._

# %% [markdown]
# ### Your solution

# %%
def prepared_copy(values):
    # TODO: implement this function.
    raise NotImplementedError("Complete Exercise 3")

# %% [markdown]
# ### Example checks
#
# Run this cell after implementing your function.

# %%
source = [5]
result = prepared_copy(source)
assert result == [5, 0, 1]
assert source == [5]
assert result is not source
assert prepared_copy([]) == [0, 1]

# %% [markdown]
# ### Your own checks
#
# Add at least one test case. Include any specific case requested in the exercise.

# %%
# Add your own checks here.

# %% [markdown]
# ## 4. A draft schedule
#
# A schedule is represented as a list of days; each day is a separate list of class names. Names are strings, with no deeper nesting.
#
# To edit a draft, a student wrote:

# %%
schedule = [["Python", "Algorithms"], ["English"]]
draft = schedule.copy()
draft[0].append("Practice")

# %%
# Inspect the original schedule and the draft.
print("Original:", schedule)
print("Draft:", draft)

# %% [markdown]
# Check whether the original schedule changed. Explain why copying the outer list was not enough.
#
# Write a function `copy_schedule(schedule)` that returns a copy with independent day lists. Use a list comprehension; do not use `copy.deepcopy`.

# %% [markdown]
# ### Your solution

# %%
def copy_schedule(schedule):
    # TODO: implement this function.
    raise NotImplementedError("Complete Exercise 4")

# %% [markdown]
# ### Example checks
#
# Run this cell after implementing your function.

# %%
schedule = [["Python", "Algorithms"], ["English"]]
draft = copy_schedule(schedule)
draft[0].append("Practice")
draft.append(["Exam"])
assert schedule == [["Python", "Algorithms"], ["English"]]
assert draft == [["Python", "Algorithms", "Practice"], ["English"], ["Exam"]]

empty_days = copy_schedule([[], []])
empty_days[0].append("Python")
assert empty_days == [["Python"], []]
assert copy_schedule([]) == []

# %% [markdown]
# Why do the strings containing class names not need to be copied separately?

# %% [markdown]
# **Your explanation or observations:**
#
# _Write your answer to the exercise question here._

# %% [markdown]
# ### Your own checks
#
# Add at least one test case. Include any specific case requested in the exercise.

# %%
# Add your own checks here.

# %% [markdown]
# ## 5. Closest to the target
#
# You are given a list of integers `values` and an integer target `target`.
#
# Write a function `closest_values(values, target)` that returns a new list of numbers ordered by increasing distance from the target. The distance is `abs(value - target)`. If two numbers have the same distance, the smaller number comes first. Preserve duplicates.
#
# Use `sorted` with the `key` parameter. Do not modify the original list.

# %% [markdown]
# ### Your solution

# %%
def closest_values(values, target):
    # TODO: implement this function.
    raise NotImplementedError("Complete Exercise 5")

# %% [markdown]
# ### Example checks
#
# Run this cell after implementing your function.

# %%
values = [8, 3, 6, 4, 6, 10]
assert closest_values(values, 5) == [4, 6, 6, 3, 8, 10]
assert values == [8, 3, 6, 4, 6, 10]
assert closest_values([-2, 2, 0], 0) == [0, -2, 2]
assert closest_values([], 5) == []

# %% [markdown]
# Create an example where sorting simply by numeric value produces a different result.

# %% [markdown]
# **Your explanation or observations:**
#
# _Write your answer to the exercise question here._

# %% [markdown]
# ### Your own checks
#
# Add at least one test case. Include any specific case requested in the exercise.

# %%
# Add your own checks here.

# %% [markdown]
# ## 6. How many sessions did each student attend?
#
# You are given a list `visits`: each element is a list of names of students who connected to a single session. A student may have reconnected, so the same name can appear several times within one session. Identical strings refer to the same student.
#
# Write a function `attendance(visits)` that returns pairs `(name, number_of_sessions_attended)`:
#
# - each session counts at most once per student;
# - students with more sessions attended come first;
# - ties are broken by name using Python's ascending string order;
# - students who never appeared in any session are not included in the result.
#
# Use a set to remove duplicates within each session and a regular dictionary for counting. Do not use `collections.Counter`, and do not modify the input data.

# %% [markdown]
# ### Your solution

# %%
def attendance(visits):
    # TODO: implement this function.
    raise NotImplementedError("Complete Exercise 6")

# %% [markdown]
# ### Example checks
#
# Run this cell after implementing your function.

# %%
visits = [
    ["Alice", "Bob", "Alice"],
    ["Bob", "Charlie"],
    ["Alice", "Charlie", "Charlie"],
    [],
]
assert attendance(visits) == [("Alice", 2), ("Bob", 2), ("Charlie", 2)]
assert attendance([["Bob", "Bob"], ["Alice", "Bob"]]) == [("Bob", 2), ("Alice", 1)]
assert attendance([]) == []
assert attendance([[], []]) == []

# %% [markdown]
# Explain what information would be lost if you first collected all names into one shared set.

# %% [markdown]
# **Your explanation or observations:**
#
# _Write your answer to the exercise question here._

# %% [markdown]
# ### Your own checks
#
# Add at least one test case. Include any specific case requested in the exercise.

# %%
# Add your own checks here.

# %% [markdown]
# ## 7. (Optional) A running balance as transactions arrive ★
#
# An optional exercise introducing `yield`.
#
# Write a generator `running_balance(changes, start=0)`. It receives a sequence of integer balance changes and yields the balance **after each transaction**, starting the calculation from `start`. Do not yield the initial balance separately.
#
# Use `yield`: this statement produces the next value and suspends the function until the next request. Keep track of the current balance without building a list of all results. The function must accept either a list or a generator as input; do not use indexing or `len(changes)`.

# %% [markdown]
# ### Your solution

# %%
def running_balance(changes, start=0):
    # TODO: implement this function.
    raise NotImplementedError("Complete Exercise 7")

# %% [markdown]
# ### Example checks
#
# Run this cell after implementing your function.

# %%
gen = running_balance([100, -30, 20], start=10)
assert next(gen) == 110
assert next(gen) == 80
assert list(gen) == [100]
assert list(gen) == []
assert list(running_balance([], start=50)) == []
assert list(running_balance(x for x in [2, -1, 3])) == [2, 1, 4]

# %% [markdown]
# Explain why the second call to `list(gen)` returns an empty list. What happens if you request only the first two balances from an infinite stream of transactions?

# %% [markdown]
# **Your explanation or observations:**
#
# _Write your answer to the exercise question here._

# %% [markdown]
# ### Your own checks
#
# Add at least one test case. Include any specific case requested in the exercise.

# %%
# Add your own checks here.
